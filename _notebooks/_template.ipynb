# %% [raw]
# ---
# layout: post
# title: "My Notebook Post"
# date: 2026-04-12
# categories: computation
# tags: python, data-science
# description: "A short description of the notebook."
# ---

# %% [markdown]
# # Introduction
#
# Write your notebook content here. Code cells, outputs, and markdown will all be converted.

# %%
print('Hello from a notebook!')
